# %%
animals = 'darke faum heron ibex koala lynx tahr xerux yak zapus'.split()

# %%
pip install columnize
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip is available: 25.1.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import columnize

# %%
table = columnize.columnize(animals)

# %%
table
# Out:
# 'darke  faum  heron  ibex  koala  lynx  tahr  xerux  yak  zapus\n'

# %%
for row in table:
    print(''.join(f'{word:10}' for word in row))
# Out:
# d
# a
# r
# k
# e
#
#
# f
# a
# u
# m
#
#
# h
# e
# r
# o
# n
#
#
# i
# b
# e
# x
#
#
# k
# o
# a
# l
# a
#
#
# l
# y
# n
# x
#
#
# t
# a
# h
# r
#
#
# x
# e
# r
# u
# x
#
#
# y
# a
# k
#
#
# z
# a
# p
# u
# s
